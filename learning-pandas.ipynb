# %% [markdown]
# <a href="https://www.kaggle.com/code/heemalichaudhari/learning-pandas?scriptVersionId=115735417" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Importing Library

# %%
import pandas as pd
